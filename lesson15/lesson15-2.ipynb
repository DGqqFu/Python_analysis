# %%
import numpy as np
np.random.seed(1)
o=np.random.randint(100,10000,size=(30, ))
o=o.cumsum()
print(o)
# Out:
# [   335   5627   6632  14545  17540  22696  22940  27265  35116  38678
#   48172  53668  59142  62204  64820  73364  77026  81890  90083  96725
#   97387 105638 108787 109640 119459 121447 122657 129042 135263 136394]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont('ChineseFont.ttf')
mpl.rc('font',family='ChineseFont')
plt.plot(range(1,31),o,color='red',linestyle='-',marker='')
plt.title('分店營收累積')
plt.xlabel('天')
plt.ylabel('累積營收')
# Out:
# Text(0, 0.5, '累積營收')

# %%
np.random.seed(42)
fiveStore = np.random.randint(100, 10000, size=(5, 30))
fiveStoreCum = fiveStore.cumsum(axis=1)
fiveStoreCum
# Out:
# array([[  7370,   8330,  13820,  19111,  24945,  31310,  31876,  36402,
#          42080,  50502,  52287,  53156,  60205,  62738,  68149,  73300,
#          79820,  81104,  85759,  89244,  95740, 104506, 113880, 116538,
#         124487, 126634, 129481, 138748, 139037, 141871],
#        [  3105,   7863,   9862,  17696,  19063,  20691,  24347,  28337,
#          37275,  42768,  51660,  60193,  67806,  70518,  77659,  87314,
#          93649,  99235, 106434, 116204, 117079, 125405, 128657, 130342,
#         134385, 142040, 145213, 146334, 150277, 158366],
#        [  9792,  16765,  22540,  22801,  27198,  28293,  36022,  45589,
#          46705,  54674,  61213,  69205,  76168,  84184,  92813,  93791,
#         103159, 108146, 113105, 119536, 128207, 136991, 144299, 149675,
#         151837, 152001, 160107, 162775, 168338, 170465],
#        [  2795,  12582,  17940,  23658,  30494,  30985,  36977,  40638,
#          46922,  50121,  56499,  64991,  68195,  75510,  78064,  87160,
#          89991,  98245, 108107, 113263, 121473, 125413, 126541, 134026,
#         134628, 141638, 150800, 157838, 162426, 162732],
#        [  5234,  11311,  19132,  26267,  27851,  35809,  36772,  39662,
#          47170,  56025,  61241,  67360,  69217,  76891,  83365,  90357,
#          92135,  95477, 100213, 101372, 108140, 111397, 117412, 127301,
#         130094, 133821, 143476, 149026, 150789, 160610]])

# %%
fontManager.addfont('ChineseFont.ttf')
mpl.rc('font',family='ChineseFont')
plt.plot(range(1,31),fiveStoreCum[0],color='red',linestyle='-',marker='',label="第1家分店")
plt.plot(range(1,31),fiveStoreCum[1],color='y',linestyle='-',marker='',label="第2家分店")
plt.plot(range(1,31),fiveStoreCum[2],color='g',linestyle='-',marker='',label="第3家分店")
plt.plot(range(1,31),fiveStoreCum[3],color='m',linestyle='-',marker='',label="第4家分店")
plt.plot(range(1,31),fiveStoreCum[4],color='c',linestyle='-',marker='',label="第5家分店")
plt.title("每家分店營收累計")
plt.xlabel("天")
plt.ylabel("累計營收")
plt.legend()
plt.show()
