# %%
import os
file_name:str = 'names.txt' 
abs_path:str = os.path.abspath(file_name)
with open(abs_path,encoding='utf-8')as file:
    names:list[str] = file.readlines()
    names = [name.rstrip('\n') for name in names] 
print(names)
file.close()
"""
import os
file_name:str = 'names.txt' 
abs_path:str = os.path.abspath(file_name)
file = open(abs_path,encoding='utf-8')
names:list[str] = file.readlines()
# new_names = []
# for name in names:
#     new_names.append(name.rstrip('\n'))
names = [name.rstrip('\n') for name in names] #list comprehensions
print(names)
file.close()
"""
"""import os
file_name:str = 'names.txt' 
abs_path:str = os.path.abspath(file_name)
file = open(abs_path,encoding='utf-8')
names:list[str] = file.readlines()
new_names = []
for name in names:
    new_names.append(name.rstrip('\n'))
nnames=[name.strip('\n') for name in names]
"""
"""import os
file_name:str = 'names.txt' 
abs_path:str = os.path.abspath(file_name)
file=open(abs_path,encoding='utf-8')
names=file.readlines()
nnames=[]
for name in names:
    nnames.append(name.rstrip('\n'))
print(nnames)
"""
"""
import os
file_name:str = 'names.txt' 
abs_path:str = os.path.abspath(file_name)
file = open(abs_path,encoding='utf-8')
names:list[str] = file.readlines()
for name in names:
    display(name.rstrip('\n'))
    break
names
"""
# Out:
# ['陳怡伶', '馮芳如', '蒙淑惠', '張軒宸', '陳向愛', '賴心怡', '王怡珊', '林詠斌', '陳淑娟', '崔孝憲', '林希啟', '楊韋廷', '陳文賢', '王士銘', '賴昌韻', '黃名明', '吳麗卿', '游治旺', '蔡嘉音', '黃靜怡', '黃淑芬', '龔姵君', '景歡燦', '李政成', '楊綺芬', '昌嘉洋', '李慈啟', '游倫城', '林淑安', '蔡士賢', '林世城', '林佳蓉', '柯宜臻', '傅佳琳', '林瑞喬', '林佳慧', '鍾俞禎', '劉慧君', '劉林中', '林怡偉', '余丞苓', '黃佩玲', '林建宏', '方雅慧', '林柏洋', '郭舜昇', '艾巧夫', '童建霖', '蔡至剛', '黃心航', '張凡成', '郭淑枝', '黃必琪', '楊健麟', '林建勳', '鄭琇亞', '王雅琴', '李美洋', '楊少亮', '王泓泰', '黃江旭', '王梅劭', '林佳光', '盧必妍', '林思賢', '鄧哲榮', '陳家年', '張俊傑', '洪阿惠', '陳彥治', '盧冠發', '程玫靖', '潘俊賢', '呂傑宣', '鄭孟芳', '彭茹靖', '王孝純', '吳昕婷', '朱惠儀', '盧文啟', '謝佳穎', '鄭憲定', '馮淑芬', '聶心怡', '黃志福', '馬彥文', '郭淑真', '吳欣書', '鄭佳玲', '黃健發', '胡姿婷', '林義皓', '胡芳瑜', '楊易政', '王德城', '劉依婷', '吳俐芷', '黃詩妃', '柯韋成', '鄧亭聿', '王雅慧', '陳凱翔', '藍哲嘉', '趙偉銘', '張韋成', '林向鈺', '周琬婷', '尚偉倫', '賴佳雯', '陳姵彬', '林群清', '趙家豪', '李政白', '林俊翔', '李進慧', '楊韻如', '藍姿婷', '劉嘉泰', '王柏聖', '孫宜珊', '戴萱能', '高士凱', '楊又源', '劉昀天', '王怡君', '余月修', '劉萬季', '陳信宏', '陳孝邦', '朱彥志', '陳奇瑄', '鄧淑娟', '陳逸凡', '張牧聿', '唐雪豪', '林康亮', '黃旻林', '蕭淑華', '劉雯芬', '陳美惠', '孫火清', '溫法堯', '錢欣潔', '陳倩潔', '李雅怡', '白美珍', '葉志峰', '黃佩芬', '黃麗美', '黃奎紹', '邱亭君', '詹忠光', '戚亨', '賴又琦', '林佳人', '黃善迪', '賴苑禾', '溫重意', '周怡啟', '王明昇', '羅佩樺', '陳家維', '張莉雯', '高俊男', '林冠蕙', '王品星', '吳孟穎', '黃雅慧', '馮耀中', '元延辛', '王坤安', '陳慧君', '張伊映', '林士凱', '蘇婷婷', '陳淑萍', '林玉佩', '謝貞妃', '杜儀鳳', '陳倩妮', '胡淑貞', '楊偉翔', '姜琬婷', '張雅芬', '葉祖雄', '沈心利', '彭虹屏', '余宗儒', '李立偉', '臧怡君', '吳振瑋', '陳建豪', '蕭怡伶', '周芷蓁', '黃偉剛', '黃婷婷', '郎慧萍', '林昱芳', '趙宛真', '白世宏', '杜明延', '許淑婷', '林珍旺', '蔡孟泉', '吳晴洋', '游一鈺', '朱士弘', '黃政甫', '游淑惠', '張婕妤', '陳逸華', '張天亨', '張嘉韋', '王志謙', '黎惠雯', '高信宏', '梁柏宇', '林志喜', '金宜芳', '簡國瑋', '林清英', '黃彥孝', '鄭奇翰', '李慶亮', '李蓉瑞', '張明惟', '游詩亞', '黃嘉琪', '張家秀', '吳柏誠', '陳得映', '郭致恬', '林麗萍', '陳樂紫', '翁鈺婷', '蔡世馨', '楊建安', '李湘婷', '鞠冠宇', '林志成', '陳信念', '林益妏', '蔡偉成', '王惠皓', '王筱婷', '楊火帆', '陳怡珊', '張慧君', '翁羽威', '羅幸娥', '陳俊憲', '洪奎夫', '翁均安', '吳明妮', '高智超', '王人仰', '劉旭士', '蘇凡菁', '謝哲維', '彭偉妃', '劉耿琦', '黃柏宇', '李佳彥', '唐翊修', '陳建香', '葉軍仰', '吳志宣', '林珈發', '黃翔杰', '郭坤花', '吳淑惠', '簡美君', '許芳如', '謝水儒', '陳怡容', '蔡欣汝', '王良斌', '周家銘', '張凱妮', '鄭淑珍', '陳嘉淑', '魏秋萍', '簡佳樺', '劉佳佩', '李彥伸', '陳筱涵', '蔡明平', '王展人', '方筠紹', '陳志偉', '錢佩豪', '陳冠霞', '潘英迪', '陳冠竹', '李淑芳', '謝南慧', '趙家豪', '龐皓芳', '張彥博']
# "\nimport os\nfile_name:str = 'names.txt' \nabs_path:str = os.path.abspath(file_name)\nfile = open(abs_path,encoding='utf-8')\nnames:list[str] = file.readlines()\nfor name in names:\n    display(name.rstrip('\n'))\n    break\nnames\n"

# %%
import os

file_name: str = 'names.txt'
abs_path: str = os.path.abspath(file_name)

with open(abs_path, encoding='utf-8') as file:
    names: list[str] = file.readlines()

name = [name.rstrip('\n') for name in names]
print(name)
# Out:
# ['陳怡伶', '馮芳如', '蒙淑惠', '張軒宸', '陳向愛', '賴心怡', '王怡珊', '林詠斌', '陳淑娟', '崔孝憲', '林希啟', '楊韋廷', '陳文賢', '王士銘', '賴昌韻', '黃名明', '吳麗卿', '游治旺', '蔡嘉音', '黃靜怡', '黃淑芬', '龔姵君', '景歡燦', '李政成', '楊綺芬', '昌嘉洋', '李慈啟', '游倫城', '林淑安', '蔡士賢', '林世城', '林佳蓉', '柯宜臻', '傅佳琳', '林瑞喬', '林佳慧', '鍾俞禎', '劉慧君', '劉林中', '林怡偉', '余丞苓', '黃佩玲', '林建宏', '方雅慧', '林柏洋', '郭舜昇', '艾巧夫', '童建霖', '蔡至剛', '黃心航', '張凡成', '郭淑枝', '黃必琪', '楊健麟', '林建勳', '鄭琇亞', '王雅琴', '李美洋', '楊少亮', '王泓泰', '黃江旭', '王梅劭', '林佳光', '盧必妍', '林思賢', '鄧哲榮', '陳家年', '張俊傑', '洪阿惠', '陳彥治', '盧冠發', '程玫靖', '潘俊賢', '呂傑宣', '鄭孟芳', '彭茹靖', '王孝純', '吳昕婷', '朱惠儀', '盧文啟', '謝佳穎', '鄭憲定', '馮淑芬', '聶心怡', '黃志福', '馬彥文', '郭淑真', '吳欣書', '鄭佳玲', '黃健發', '胡姿婷', '林義皓', '胡芳瑜', '楊易政', '王德城', '劉依婷', '吳俐芷', '黃詩妃', '柯韋成', '鄧亭聿', '王雅慧', '陳凱翔', '藍哲嘉', '趙偉銘', '張韋成', '林向鈺', '周琬婷', '尚偉倫', '賴佳雯', '陳姵彬', '林群清', '趙家豪', '李政白', '林俊翔', '李進慧', '楊韻如', '藍姿婷', '劉嘉泰', '王柏聖', '孫宜珊', '戴萱能', '高士凱', '楊又源', '劉昀天', '王怡君', '余月修', '劉萬季', '陳信宏', '陳孝邦', '朱彥志', '陳奇瑄', '鄧淑娟', '陳逸凡', '張牧聿', '唐雪豪', '林康亮', '黃旻林', '蕭淑華', '劉雯芬', '陳美惠', '孫火清', '溫法堯', '錢欣潔', '陳倩潔', '李雅怡', '白美珍', '葉志峰', '黃佩芬', '黃麗美', '黃奎紹', '邱亭君', '詹忠光', '戚亨', '賴又琦', '林佳人', '黃善迪', '賴苑禾', '溫重意', '周怡啟', '王明昇', '羅佩樺', '陳家維', '張莉雯', '高俊男', '林冠蕙', '王品星', '吳孟穎', '黃雅慧', '馮耀中', '元延辛', '王坤安', '陳慧君', '張伊映', '林士凱', '蘇婷婷', '陳淑萍', '林玉佩', '謝貞妃', '杜儀鳳', '陳倩妮', '胡淑貞', '楊偉翔', '姜琬婷', '張雅芬', '葉祖雄', '沈心利', '彭虹屏', '余宗儒', '李立偉', '臧怡君', '吳振瑋', '陳建豪', '蕭怡伶', '周芷蓁', '黃偉剛', '黃婷婷', '郎慧萍', '林昱芳', '趙宛真', '白世宏', '杜明延', '許淑婷', '林珍旺', '蔡孟泉', '吳晴洋', '游一鈺', '朱士弘', '黃政甫', '游淑惠', '張婕妤', '陳逸華', '張天亨', '張嘉韋', '王志謙', '黎惠雯', '高信宏', '梁柏宇', '林志喜', '金宜芳', '簡國瑋', '林清英', '黃彥孝', '鄭奇翰', '李慶亮', '李蓉瑞', '張明惟', '游詩亞', '黃嘉琪', '張家秀', '吳柏誠', '陳得映', '郭致恬', '林麗萍', '陳樂紫', '翁鈺婷', '蔡世馨', '楊建安', '李湘婷', '鞠冠宇', '林志成', '陳信念', '林益妏', '蔡偉成', '王惠皓', '王筱婷', '楊火帆', '陳怡珊', '張慧君', '翁羽威', '羅幸娥', '陳俊憲', '洪奎夫', '翁均安', '吳明妮', '高智超', '王人仰', '劉旭士', '蘇凡菁', '謝哲維', '彭偉妃', '劉耿琦', '黃柏宇', '李佳彥', '唐翊修', '陳建香', '葉軍仰', '吳志宣', '林珈發', '黃翔杰', '郭坤花', '吳淑惠', '簡美君', '許芳如', '謝水儒', '陳怡容', '蔡欣汝', '王良斌', '周家銘', '張凱妮', '鄭淑珍', '陳嘉淑', '魏秋萍', '簡佳樺', '劉佳佩', '李彥伸', '陳筱涵', '蔡明平', '王展人', '方筠紹', '陳志偉', '錢佩豪', '陳冠霞', '潘英迪', '陳冠竹', '李淑芳', '謝南慧', '趙家豪', '龐皓芳', '張彥博']

# %%
import random
student_names=random.sample(names,k=50)
student=[]
for name in student_names:
    stu_dict = dict()
    stu_dict["姓名"] = name
    stu_dict["國文"] = random.randint(50, 100)
    stu_dict["英文"] = random.randint(50, 100)
    stu_dict["數學"] = random.randint(50, 100)
    student.append(stu_dict)
    
student
# Out:
# [{'姓名': '林建勳', '國文': 91, '英文': 80, '數學': 70},
#  {'姓名': '李政白', '國文': 90, '英文': 88, '數學': 93},
#  {'姓名': '潘俊賢', '國文': 82, '英文': 70, '數學': 70},
#  {'姓名': '葉軍仰', '國文': 60, '英文': 70, '數學': 61},
#  {'姓名': '王惠皓', '國文': 58, '英文': 53, '數學': 61},
#  {'姓名': '朱士弘', '國文': 92, '英文': 59, '數學': 84},
#  {'姓名': '馬彥文', '國文': 68, '英文': 72, '數學': 51},
#  {'姓名': '蕭淑華', '國文': 78, '英文': 60, '數學': 63},
#  {'姓名': '鄭孟芳', '國文': 56, '英文': 80, '數學': 83},
#  {'姓名': '黃詩妃', '國文': 62, '英文': 78, '數學': 89},
#  {'姓名': '黃婷婷', '國文': 96, '英文': 94, '數學': 78},
#  {'姓名': '林珍旺', '國文': 60, '英文': 86, '數學': 76},
#  {'姓名': '趙家豪', '國文': 72, '英文': 85, '數學': 66},
#  {'姓名': '彭虹屏', '國文': 60, '英文': 94, '數學': 66},
#  {'姓名': '陳信宏', '國文': 84, '英文': 71, '數學': 97},
#  {'姓名': '李雅怡', '國文': 53, '英文': 50, '數學': 91},
#  {'姓名': '陳嘉淑', '國文': 62, '英文': 94, '數學': 62},
#  {'姓名': '高智超', '國文': 84, '英文': 53, '數學': 68},
#  {'姓名': '盧冠發', '國文': 82, '英文': 68, '數學': 66},
#  {'姓名': '趙偉銘', '國文': 51, '英文': 67, '數學': 75},
#  {'姓名': '錢佩豪', '國文': 52, '英文': 61, '數學': 70},
#  {'姓名': '劉雯芬', '國文': 83, '英文': 66, '數學': 89},
#  {'姓名': '林淑安', '國文': 61, '英文': 90, '數學': 89},
#  {'姓名': '林建宏', '國文': 77, '英文': 91, '數學': 83},
#  {'姓名': '周怡啟', '國文': 96, '英文': 97, '數學': 86},
#  {'姓名': '吳淑惠', '國文': 98, '英文': 51, '數學': 83},
#  {'姓名': '彭茹靖', '國文': 80, '英文': 77, '數學': 59},
#  {'姓名': '黃志福', '國文': 60, '英文': 78, '數學': 81},
#  {'姓名': '張韋成', '國文': 98, '英文': 64, '數學': 92},
#  {'姓名': '林麗萍', '國文': 87, '英文': 82, '數學': 65},
#  {'姓名': '李湘婷', '國文': 82, '英文': 93, '數學': 99},
#  {'姓名': '簡國瑋', '國文': 57, '英文': 100, '數學': 52},
#  {'姓名': '謝南慧', '國文': 96, '英文': 57, '數學': 82},
#  {'姓名': '林佳蓉', '國文': 55, '英文': 76, '數學': 56},
#  {'姓名': '郎慧萍', '國文': 71, '英文': 90, '數學': 66},
#  {'姓名': '劉萬季', '國文': 98, '英文': 76, '數學': 93},
#  {'姓名': '洪奎夫', '國文': 78, '英文': 95, '數學': 82},
#  {'姓名': '詹忠光', '國文': 62, '英文': 55, '數學': 79},
#  {'姓名': '白世宏', '國文': 97, '英文': 77, '數學': 67},
#  {'姓名': '林佳慧', '國文': 96, '英文': 63, '數學': 100},
#  {'姓名': '黃善迪', '國文': 71, '英文': 67, '數學': 60},
#  {'姓名': '王良斌', '國文': 59, '英文': 66, '數學': 84},
#  {'姓名': '孫宜珊', '國文': 93, '英文': 84, '數學': 51},
#  {'姓名': '鍾俞禎', '國文': 51, '英文': 98, '數學': 76},
#  {'姓名': '黃健發', '國文': 96, '英文': 67, '數學': 56},
#  {'姓名': '柯宜臻', '國文': 60, '英文': 83, '數學': 98},
#  {'姓名': '王柏聖', '國文': 72, '英文': 61, '數學': 59},
#  {'姓名': '翁鈺婷', '國文': 83, '英文': 66, '數學': 52},
#  {'姓名': '蔡偉成', '國文': 67, '英文': 76, '數學': 66},
#  {'姓名': '尚偉倫', '國文': 96, '英文': 73, '數學': 98}]

# %%
import csv
from csv import DictWriter

field_names = list(student[0].keys())
with open("students.csv",mode='w',encoding='utf-8',newline='') as file:
    writer= csv.DictWriter(file,field_names)
    writer.writeheader()
    writer.writerows(student)

print("students.csv已經存檔")
# Out:
# students.csv已經存檔
